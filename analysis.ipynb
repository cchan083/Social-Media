# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('social_media_entertainment_data.csv')
df.head()
# Out:
#    User ID  Age  Gender  Country  Daily Social Media Time (hrs)  \
# 0        1   32   Other  Germany                           4.35
# 1        2   62   Other    India                           4.96
# 2        3   51  Female      USA                           6.78
# 3        4   44  Female    India                           5.06
# 4        5   21   Other  Germany                           2.57
#
#    Daily Entertainment Time (hrs)  Social Media Platforms Used  \
# 0                            4.08                            5
# 1                            4.21                            2
# 2                            1.77                            4
# 3                            9.21                            3
# 4                            1.30                            4
#
#   Primary Platform  Daily Messaging Time (hrs)  \
# 0           TikTok                        0.35
# 1          YouTube                        2.55
# 2         Facebook                        2.09
# ...

# %%
df.loc[df['Country'] == 'USA']
# Out:
#         User ID  Age  Gender Country  Daily Social Media Time (hrs)  \
# 2             3   51  Female     USA                           6.78
# 7             8   58  Female     USA                           4.20
# 23           24   32  Female     USA                           0.78
# 24           25   36  Female     USA                           7.72
# 31           32   21    Male     USA                           0.62
# ...         ...  ...     ...     ...                            ...
# 299979   299980   35  Female     USA                           5.44
# 299986   299987   30  Female     USA                           1.28
# 299987   299988   48   Other     USA                           3.16
# 299989   299990   24   Other     USA                           4.37
# 299998   299999   15    Male     USA                           6.47
#
#         Daily Entertainment Time (hrs)  Social Media Platforms Used  \
# 2                                 1.77                            4
# ...

# %%
df['Country'].unique()
# Out:
# array(['Germany', 'India', 'USA', 'Canada', 'UK', 'Australia'],
#       dtype=object)

# %%
countries = df['Country'].value_counts()
fig, ax = plt.subplots(figsize=(7,6))
countries.plot(
    kind='bar',
    rot=45,
    ax=ax
)
# Out:
# <Axes: xlabel='Country'>

# %%
df = df.rename(columns={"Daily Social Media Time (hrs)": "daily social media"})
df
# Out:
#         User ID  Age  Gender  Country  daily social media  \
# 0             1   32   Other  Germany                4.35
# 1             2   62   Other    India                4.96
# 2             3   51  Female      USA                6.78
# 3             4   44  Female    India                5.06
# 4             5   21   Other  Germany                2.57
# ...         ...  ...     ...      ...                 ...
# 299995   299996   17  Female   Canada                1.98
# 299996   299997   45  Female  Germany                3.78
# 299997   299998   45    Male   Canada                6.25
# 299998   299999   15    Male      USA                6.47
# 299999   300000   49   Other  Germany                1.27
#
#         Daily Entertainment Time (hrs)  Social Media Platforms Used  \
# 0                                 4.08                            5
# 1                                 4.21                            2
# ...

# %%
df_usa = df.loc[df['Country'] == 'USA']
#df_usa = df.drop(['Ad Interaction Count', 'Time on Educational Platforms (hrs)', 'Parental Status', 'Tech Savviness Level (scale 1-10)', 'Social Isolation Feeling (scale 1-10)', 'Monthly Expenditure on Entertainment (USD)'], axis=0)
df_usa.head()
# Out:
#     User ID  Age  Gender Country  daily social media  \
# 2         3   51  Female     USA                6.78
# 7         8   58  Female     USA                4.20
# 23       24   32  Female     USA                0.78
# 24       25   36  Female     USA                7.72
# 31       32   21    Male     USA                0.62
#
#     Daily Entertainment Time (hrs)  Social Media Platforms Used  \
# 2                             1.77                            4
# 7                             2.77                            4
# 23                            0.55                            2
# 24                            5.83                            4
# 31                            7.94                            1
#
#    Primary Platform  Daily Messaging Time (hrs)  \
# 2          Facebook                        2.09
# 7          Facebook                        3.54
# 23         Facebook                        0.57
# 24          YouTube                        1.37
# ...

# %%
df_instagram = (df.loc[df['Primary Platform'] == 'Instagram'])

# %%
df_instagram.loc[df['daily social media'] > 5]
# Out:
#         User ID  Age  Gender    Country  daily social media  \
# 22           23   28    Male     Canada                7.03
# 69           70   64   Other  Australia                5.02
# 80           81   57    Male         UK                6.05
# 82           83   30   Other     Canada                5.71
# 111         112   21    Male         UK                7.68
# ...         ...  ...     ...        ...                 ...
# 299926   299927   28  Female         UK                6.64
# 299965   299966   58    Male         UK                7.80
# 299966   299967   50   Other    Germany                5.78
# 299971   299972   28    Male      India                7.24
# 299980   299981   27    Male         UK                7.84
#
#         Daily Entertainment Time (hrs)  Social Media Platforms Used  \
# 22                                3.96                            3
# 69                                8.51                            5
# ...

# %%
df_teenagers_adults = df.loc[(df['Age'] > 11) & (df['Age'] < 25)]
df_teenagers_adults.plot(
    kind='hist',
    x='daily social media',
    y='Age'
)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df_teenagers_adults['Gender'].value_counts()
# Out:
# Gender
# Other     23181
# Female    22984
# Male      22915
# Name: count, dtype: int64

# %%
male = df_teenagers_adults.loc[df['Gender'] =='Male']
male['daily social media'].mean()
# Out:
# np.float64(4.253882173248964)

# %%
# Out:
# Thre are 8, 2 tens, and 3 ones.
